# %%
aList = [1,2,3]
print (aList)
print (type(aList))
aList
# Out:
# [1, 2, 3]
# <class 'list'>
# [1, 2, 3]

# %%
aDict = { 'a' : '1', 'a' : '2', 'c' : '3', 'd' : '4'}
print (aDict)
print (type(aDict))

print ("aList is of type %s and contains %s, aDict is of type %s and contains %s" % \
       (type(aList), aList, type(aDict), aDict))
# Out:
# {'a': '2', 'c': '3', 'd': '4'}
# <class 'dict'>
# aList is of type <class 'list'> and contains [1, 2, 3], aDict is of type <class 'dict'> and contains {'a': '2', 'c': '3', 'd': '4'}

# %% [markdown]
# here are some comments on the next cell

# %% [markdown]
# test

# %%
'''
aList = [ ]
aList.append('a')
aList.append(2)
'''

#aList
def createList(arg1):
    aList = [ ]
    #aList.append('a')
    #aList.append(2)
    aList.append(arg1)
    return aList

aListLocal = createList('abc')
aListLocal.append('def')
aListLocal.pop()
print(aListLocal)
# Out:
# ['abc']

# %%
aDict =  { "a" : "b", "e": "f"}
aDict["c"] = "d"
aDict["z"] = 'y'
print(aDict)
print(aDict['a'])

for key,value in aDict.items():
    print(" %s : %s" % (key, value))
# Out:
# {'a': 'b', 'e': 'f', 'c': 'd', 'z': 'y'}
# b
#  a : b
#  e : f
#  c : d
#  z : y

# %%
aList = [1,2,3]
print(aList[1])

bob = "name"
bill = [1,2,3,4,'c','d']

print(bob + " " + "bill")
# Out:
# 2
# name bill

# %% [markdown]
# ## this is not code

# %%
for i in aList:
    print (i)
    print("hello")
# Out:
# 1
# hello
# 2
# hello
# 3
# hello

# %%
for a,b in aDict.items():
    print ("%s , %s" % (a,b))

for i in aDict:
    print (i)
    print(aDict[i])
# Out:
# a , b
# e , f
# c , d
# z , y
# a
# b
# e
# f
# c
# d
# z
# y

# %%
i = 0
while i < 3:
    i = 1
    print (i)
# Out:
# 1
# 2
# 3

# %%
def testFunction(a='???'):
    print ("hello testFunction %s" % a)

testFunction("!!!")
testFunction()
# Out:
# hello testFunction !!!
# hello testFunction ???
