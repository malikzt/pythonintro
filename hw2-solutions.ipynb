# %% [markdown]
# # Homework 2
# # your name:
# ## Problem 1 (40 points)
# Please answer the following four questions:

# %% [markdown]
# ### Question 1
#
# In this scenario, two friends are eating dinner at a restaurant. The bill comes in the amount of 47.28 dollars. The friends decide to split the bill evenly between them, after adding 15% tip for the service. Calculate the tip, the total amount to pay, and each friend's share, then output a message saying "Each person needs to pay: " followed by the resulting number.

# %%
bill = 47.28
tip = bill * 0.15
total = bill + tip
share = total/2 
print( "Each person needs to pay: " + str(share))
# Out:
# Each person needs to pay: 27.186

# %% [markdown]
# ### Question 2
# This code is supposed to take two numbers, divide one by another so that the result is equal to 1, and display the result on the screen. Unfortunately, there is an error in the code. Find the error and fix it, so that the output is correct.

# %%
numerator = 10
denominator = 10
result = numerator / denominator
print(result)
# Out:
# 1.0

# %% [markdown]
# ### Question 3
# Combine the variables to display the sentence "How do you like Python so far?"

# %%
word1 = "How"
word2 = "do"
word3 = "you"
word4 = "like"
word5 = "Python"
word6 = "so"
word7 = "far?"

print(word1 + " " + word2 + " " + word3 + " " + word4 + " " + word5 + " " + word6 + " " + word7)
# Out:
# How do you like Python so far?

# %% [markdown]
# ### Question 4
# This code is supposed to display "2 + 2 = 4" on the screen, but there is an error. Find the error in the code and fix it, so that the output is correct.

# %%
print("2 + 2 = " + str(2 + 2))
# Out:
# 2 + 2 = 4

# %% [markdown]
# ### Question 5 (10 points)
# ![projectile.jpg](attachment:projectile.jpg)
# A simple physics problem that can be solved using Python is the calculation of projectile motion.
#
# Projectile motion is the motion of an object thrown or projected into the air, subject to only the acceleration of gravity. The initial velocity, launch angle, and height can be used to calculate the range, maximum height, and time of flight for the projectile.
#
# Please write a code in Python that calculates the range of a projectile given its initial velocity and launch angle:
#
# hints: use ```input``` and ``` float```

# %%
import math

def projectile_range(v, theta):
    return r

v = float(input("Enter the initial velocity (m/s): "))
theta = float(input("Enter the launch angle (degrees): "))
g = 9.8 #  (m/s^2)
r = (v**2) * math.sin(2 * math.radians(2*theta)) / g
print("range = ", r, 'm')
# Out:
# Enter the initial velocity (m/s): 5
# Enter the launch angle (degrees): 6
# range =  1.0375934772341842 m

# %% [markdown]
# ### Question 6
# Dictionaries don't have index orders, so speaking about them regarding their first item or last item is not very correct. Next time you print a dictionary it may have a different order than you saw before. Instead they have keys, and we can use keys to call their values.
#
# What it means Hello in French?

# %%
dict={"Cake": "Gateau", "country": "Pays", "born": "nee", "teacher": "Enseignants", "student": "etudient", "Hello": "Bonjour"}
answer_1 = ___
print(answer_1)

# %% [markdown]
# Dictionaries can have nested data too. Also, you can add a new key to a dictionary as they are mutable (changeable). Try to add the key "work" to dict with value you got from google translate.

# %%
dict={"Cake": "Gateau", "country": "Pays", "born": "nee", "teacher": "Enseignants", "student": "etudient", "Hello": "Bonjour"}
answer_1 = dict["Hello"]
print(answer_1)
# Out:
# Bonjour

# %% [markdown]
# Using .items() method generate a list of tuples consisted of each key value pair.

# %%
dict={"Cake": "Gateau", "country": "Pays", "born": "nee", "teacher": "Enseignants", "student": "etudient", "Hello": "Bonjour","work":"travail"}
#Type your answer below.
ans_1= list(dict.items())

print(ans_1)
# Out:
# [('Cake', 'Gateau'), ('country', 'Pays'), ('born', 'nee'), ('teacher', 'Enseignants'), ('student', 'etudient'), ('Hello', 'Bonjour'), ('work', 'travail')]

# %% [markdown]
# ### Question 7
# Assign all the elements in the list "lst" except for first element of it to answer_1 on line 2

# %%
lst=[11, 100, 99, 1000, 999]
answer_1=
print(answer_1)
# Out:
#   File "C:\Users\bahaag\AppData\Local\Temp\ipykernel_15320\427794206.py", line 2
#     answer_1=
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ```.append``` method will let you add items to your lists.
#
# Add the string "pajamas" to the list answer_1 with .append() method.

# %%
lst=[11, 100, 99, 1000, 999]
answer_1=lst[1:]

print(answer_1)

# %% [markdown]
# .insert() lets you specify the index you want to add your item.
#
# this time insert "slippers" to index 5 of answer_1 list.

# %% [markdown]
# ## Problem 2 (20 points)
# 1) Write a Python program to concatenate following dictionaries to create a new one.
#
# ```dic1={1:10, 2:20}
# dic2={1:30, 4:40}
# dic3={5:50,6:60}```

# %%
dic1={1:10, 2:20}
dic2={1:30, 4:40}
dic3={5:50,6:60}
dic4 = {}
for d in (dic1, dic2, dic3): 
    dic4.update(d)
print(dic4)

# %% [markdown]
# 2) Looking to your results above, one can say that the code you wrote updated the value of key 1 by the latest dictionarry list. Please re-write the code to do not update an existing key.
#
# The outpout should be then: {1: 10, 2: 20, 4: 40, 5: 50, 6: 60}
#
# hints: use ``` not in ``` or ```in```

# %%
# method 1
dic1={1:10, 2:20}
dic2={1:30, 4:40}
dic3={5:50,6:60}
dic4 = {}
lis =[]
for dic in (dic1, dic2, dic3):
    for d in dic: 
        if d not in lis:
            lis.append(d)
            dic4.update({d:dic[d]})
print(dic4)

# %%
# method 2
dic1={1:10, 2:20}
dic2={1:30, 4:40}
dic3={5:50,6:60}
dicmerged= dic1.copy()
for key,value in dic2.items():
    if key not in dicmerged:
        dicmerged[key]=dic2[key]
for key, value in dic3.items():
    if key not in dicmerged:
        dicmerged[key]=dic3[key]
print(dicmerged)

# %% [markdown]
# ## Probelm 3 (40 points)
# The best method to prcatice loops programming with if statement if what we called "the pattern program". These kind of problems are not usually trivial. If you are able to solve the following tasks correctly, it means you are a good programmer.
#
# ### Part A (20 points):
# Let's start by an easy example as a practice:

# %%
num = int(input("Enter the number of rows:"))
row = 0
while row<num:
    for ii in range(row+1):
        print("*",end=" ")
    print("")
    row += 1

# %% [markdown]
# The code above asks the user for a number of rows to print stars in right triangle shape using for and while loop. The number of rows is defined by the user and the base of the triangle has number of stars equal to the number of raws
#
# 1)In this part, please rewrite the code to have only for loops in it

# %%
num = int(input("Enter the number of rows:"))
for row in range(num):
    for ii in range(row+1):
        print("*",end=" ")
    print("")

# %% [markdown]
# 2)In this part, please rewrite the code to have only while loops in it

# %%
num = int(input("Enter the number of rows:"))
row = 0
while row<num:
    ii = 0
    while ii < (row+1):
        print("*",end=" ")
        ii +=1
    print("")
    row += 1

# %% [markdown]
# 3) In this part, please rewrite the codes anove to have only one 'for' loop or one 'while' loop (instead of two loops). Again only one 'for' in your code.**

# %%
num = 5
for row in range(num):
    print(row*"* ",end=" ")
    print("")

# %% [markdown]
# ### Part B (20 points):
# In this part we would like to draw a trangle shpae of type isoceles where the number of rows is given by the user:
#
# here num = 12
#
#                       *
#                     * * *s
#                   * * * * *
#                 * * * * * * *
#               * * * * * * * * *
#             * * * * * * * * * * *
#           * * * * * * * * * * * * *
#         * * * * * * * * * * * * * * *
#       * * * * * * * * * * * * * * * * *
#     * * * * * * * * * * * * * * * * * * *
#   * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
#
# 1) write the code using only for loops

# %%
num = int(input("Enter the number of rows:"))
for inum in range(0,num):
    for iu in range(0,num - inum):
        print(" ",end=" ")
    for ic in range(0,2*inum-1):
        print("* ",end="")
    print("")

# %% [markdown]
# 2) write the code using only while loops

# %%
num = int(input("Enter the number of rows:"))
inum = 0
while inum < num:
    iu = 0
    while iu < (num - inum):
        print(" ",end=" ")
        iu +=1
    ic = 0
    while ic < (2*inum-1):
        print("* ",end="")
        ic +=1
    print("")
    inum +=1
