# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "drive/MyDrive/enpm808w-datasets"
# Out:
# all_nyt.zip		    datasets_7001_312628_acs2015_county_data.csv
# avocado-updated-2020.csv    financial_sentimental_analysis_all-data.csv
# BeerDataScienceProject.zip  homeprices.csv
# bikeshare		    housing
# birthwt.csv		    hw3-data
# corpus.txt		    nyt1_sample.csv

# %%
#path = '/Users/apseyed/code/datasets'
#os.chdir(path)
df = pd.read_csv('drive/MyDrive/enpm808w-datasets/datasets_7001_312628_acs2015_county_data.csv')
df.head(3)
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
#
#    Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4  ...   0.5          1.3         1.8         26.5     23986
# 1     0.6  ...   1.0          1.4         3.9         26.4     85953
# 2     0.2  ...   1.8          1.5         1.6         24.1      8597
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0         73.6        20.9           5.5         0.0           7.6
# 1         81.5        12.3           5.8         0.4           7.5
# 2         71.8        20.8           7.3         0.1          17.6
#
# [3 rows x 37 columns]

# %%
df.shape
# Out:
# (3220, 37)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CensusId         3220 non-null   int64
#  1   State            3220 non-null   object
#  2   County           3220 non-null   object
#  3   TotalPop         3220 non-null   int64
#  4   Men              3220 non-null   int64
#  5   Women            3220 non-null   int64
#  6   Hispanic         3220 non-null   float64
#  7   White            3220 non-null   float64
#  8   Black            3220 non-null   float64
#  9   Native           3220 non-null   float64
#  10  Asian            3220 non-null   float64
#  11  Pacific          3220 non-null   float64
#  12  Citizen          3220 non-null   int64
#  13  Income           3219 non-null   float64
#  14  IncomeErr        3219 non-null   float64
#  15  IncomePerCap     3220 non-null   int64
# ...

# %%
df.describe()
# Out:
#            CensusId      TotalPop           Men         Women     Hispanic  \
# count   3220.000000  3.220000e+03  3.220000e+03  3.220000e+03  3220.000000
# mean   31393.605280  9.940935e+04  4.889694e+04  5.051241e+04    11.011522
# std    16292.078954  3.193055e+05  1.566813e+05  1.626620e+05    19.241380
# min     1001.000000  8.500000e+01  4.200000e+01  4.300000e+01     0.000000
# 25%    19032.500000  1.121800e+04  5.637250e+03  5.572000e+03     1.900000
# 50%    30024.000000  2.603500e+04  1.293200e+04  1.305700e+04     3.900000
# 75%    46105.500000  6.643050e+04  3.299275e+04  3.348750e+04     9.825000
# max    72153.000000  1.003839e+07  4.945351e+06  5.093037e+06    99.900000
#
#              White        Black       Native        Asian      Pacific  ...  \
# count  3220.000000  3220.000000  3220.000000  3220.000000  3220.000000  ...
# mean     75.428789     8.665497     1.723509     1.229068     0.082733  ...
# ...

# %%
df['County'].groupby(df['State']).value_counts()
# Out:
# State      County
# Alabama    Autauga        1
#            Baldwin        1
#            Barbour        1
#            Bibb           1
#            Blount         1
#            Bullock        1
#            Butler         1
#            Calhoun        1
#            Chambers       1
#            Cherokee       1
#            Chilton        1
#            Choctaw        1
#            Clarke         1
#            Clay           1
#            Cleburne       1
#            Coffee         1
#            Colbert        1
#            Conecuh        1
#            Coosa          1
#            Covington      1
#            Crenshaw       1
#            Cullman        1
#            Dale           1
#            Dallas         1
#            DeKalb         1
#            Elmore         1
#            Escambia       1
#            Etowah         1
#            Fayette        1
#            Franklin       1
#                          ..
# Wisconsin  Washburn       1
# ...

# %%
df['County'].value_counts().head()
# Out:
# Washington    31
# Jefferson     26
# Franklin      25
# Lincoln       24
# Jackson       24
# Name: County, dtype: int64

# %%
df2 = df[df['State'] == 'Wyoming']
df2.head()
# Out:
#       CensusId    State    County  TotalPop    Men  Women  Hispanic  White  \
# 3119     56001  Wyoming    Albany     37565  19692  17873       9.1   83.4
# 3120     56003  Wyoming  Big Horn     11895   6002   5893       8.9   88.1
# 3121     56005  Wyoming  Campbell     48013  24914  23099       8.2   87.9
# 3122     56007  Wyoming    Carbon     15739   8592   7147      17.4   78.4
# 3123     56009  Wyoming  Converse     14101   7118   6983       7.5   89.1
#
#       Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 3119    1.3     0.7  ...   9.8          5.6         5.9         12.8
# 3120    0.1     1.1  ...   7.0          2.6         5.7         16.9
# 3121    0.8     1.0  ...   1.4          2.6         2.2         20.2
# 3122    1.4     0.6  ...   4.2          1.5         5.4         17.4
# 3123    0.0     0.2  ...   2.0          1.4         4.8         24.2
#
#       Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  \
# ...

# %%
for i in df:
    column = df[i]
    print(i)
    print(column.nunique())
# Out:
# CensusId
# 3220
# State
# 52
# County
# 1928
# TotalPop
# 3164
# Men
# 3098
# Women
# 3105
# Hispanic
# 466
# White
# 721
# Black
# 487
# Native
# 183
# Asian
# 131
# Pacific
# 27
# Citizen
# 3146
# Income
# 3066
# IncomeErr
# 2329
# IncomePerCap
# 2962
# IncomePerCapErr
# 1758
# Poverty
# 394
# ChildPoverty
# 544
# Professional
# 344
# Service
# 228
# Office
# 202
# Construction
# 237
# Production
# 292
# Drive
# 365
# Carpool
# 189
# Transit
# 119
# Walk
# 171
# OtherTransp
# 93
# WorkAtHome
# 188
# MeanCommute
# 309
# Employed
# 3098
# PrivateWork
# 381
# PublicWork
# 322
# SelfEmployed
# 221
# FamilyWork
# 39
# Unemployment
# 230

# %%
#show all columns

pd.options.display.max_columns = None
pd.options.display.max_rows = None


#Showing nulls
null_rows = df[df.isnull().any(axis=1)] #will return rows that have a null value in any column
null_rows.head(10)
# Out:
#       CensusId   State   County  TotalPop  Men  Women  Hispanic  White  Black  \
# 548      15005  Hawaii  Kalawao        85   42     43       4.7   37.6    0.0
# 2673     48301   Texas   Loving       117   74     43      35.0   41.0    0.0
#
#       Native  Asian  Pacific  Citizen   Income  IncomeErr  IncomePerCap  \
# 548      0.0   21.2     35.3       80  66250.0     9909.0         46769
# 2673    12.8    0.0      0.0       98      NaN        NaN         25877
#
#       IncomePerCapErr  Poverty  ChildPoverty  Professional  Service  Office  \
# 548              8448     15.2           NaN          31.3     23.4    21.9
# 2673             6544     28.9           0.0          22.6     22.6    32.3
#
#       Construction  Production  Drive  Carpool  Transit  Walk  OtherTransp  \
# 548            4.7        18.8   34.3      7.5      0.0  40.3         14.9
# 2673           4.8        17.7   64.5     11.3      0.0   8.1          0.0
#
# ...

# %%
#percentage of values that are null by column
df.isnull().sum()*100/df.isnull().count().sort_values(ascending=False)
# Out:
# Asian              0.000000
# Black              0.000000
# Carpool            0.000000
# CensusId           0.000000
# ChildPoverty       0.031056
# Citizen            0.000000
# Construction       0.000000
# County             0.000000
# Drive              0.000000
# Employed           0.000000
# FamilyWork         0.000000
# Hispanic           0.000000
# Income             0.031056
# IncomeErr          0.031056
# IncomePerCap       0.000000
# IncomePerCapErr    0.000000
# MeanCommute        0.000000
# Men                0.000000
# Native             0.000000
# Office             0.000000
# OtherTransp        0.000000
# Pacific            0.000000
# Poverty            0.000000
# PrivateWork        0.000000
# Production         0.000000
# Professional       0.000000
# PublicWork         0.000000
# SelfEmployed       0.000000
# Service            0.000000
# State              0.000000
# TotalPop           0.000000
# Transit            0.000000
# Unemployment       0.000000
# ...

# %%
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns
    
missing_values_table(df)
# Out:
# Your selected dataframe has 37 columns.
# There are 3 columns that have missing values.
#               Missing Values  % of Total Values
# Income                     1                0.0
# IncomeErr                  1                0.0
# ChildPoverty               1                0.0

# %%
ax1 = sns.scatterplot(x="Men", y="Women", data=df)

# %%
ax = sns.distplot(df.Black)

# %%
sns.pairplot(df, vars=['Men', 'Women', 'Hispanic', 'White', 'Black'])

# %%
#look at correlation 
#Had to set limits to view full heatmap
ax= sns.set_context('paper')
ax= plt.figure(figsize=(7,7))

df1 = df[['TotalPop', 'Construction','ChildPoverty', 'PublicWork', 'Office', 'Service']]

broad_corr = df1.corr()
ax=sns.heatmap(broad_corr, annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()
